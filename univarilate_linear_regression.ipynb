# %% [markdown]
# <a href="https://colab.research.google.com/github/jamessj0412/fmllab/blob/main/univarilate_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import linear_model

# %%
data = pd.read_csv("/content/archive.zip")
data.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['RM'].plot(kind='hist', bins=20, title='RM')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['LSTAT'].plot(kind='hist', bins=20, title='LSTAT')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['PTRATIO'].plot(kind='hist', bins=20, title='PTRATIO')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['MEDV'].plot(kind='hist', bins=20, title='MEDV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
X = data.drop('MEDV',  axis=1).values
Y = data['MEDV'].values

# %%
X_rooms = X[:, 2]

# %%
type(X_rooms), type(Y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
X_rooms.shape, Y.shape
# Out:
# ((489,), (489,))

# %%
X_rooms = X_rooms.reshape(-1,1)
Y = Y.reshape(-1,1)

# %%
X_rooms.shape, Y.shape
# Out:
# ((489, 1), (489, 1))

# %%
plt.scatter(X_rooms, Y)
plt.xlabel('Number of rooms')
plt.ylabel('Values of house /1000($)')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(X_rooms, Y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error
Y_pred = reg.predict(X_rooms)

# %%
prediction_space = np.linspace(min(X_rooms), max(X_rooms)).reshape(-1,1)

# %%
plt.scatter(X_rooms, Y, color='blue')
plt.plot(X_rooms, reg.predict(X_rooms), color='red', linewidth=3)
plt.show()

# %%
plt.scatter(X_rooms, Y, color='blue')
plt.plot(prediction_space, reg.predict(prediction_space), color='black', linewidth=3)
plt.show()
